# %%
# Import packages
import requests
from bs4 import BeautifulSoup

# %%
# Specify url: url
url = 'https://aneeshdurg.me/blog/'

# Package the request, send the request and catch the response: r
r = requests.get(url)

# Extracts the response as html: html_doc

html_doc = r.text
# Create a BeautifulSoup object from the HTML: soup
soup = BeautifulSoup(html_doc)

# Prettify the BeautifulSoup object: pretty_soup
pretty_soup= soup.prettify()

# Print the response
print(pretty_soup)
# Out:
# <!DOCTYPE html>
# <html>
#  <head>
#   <link href="favicon.ico" rel="icon" type="image/x-icon"/>
#   <script src="https://polyfill.io/v3/polyfill.min.js?features=es6">
#   </script>
#   <script async="" id="MathJax-script" src="https://cdn.jsdelivr.net/npm/mathjax@3/es5/tex-mml-chtml.js">
#   </script>
#   <title>
#    aneesh durg – exploring the world with 1s and 0s
#   </title>
#   <meta charset="utf-8"/>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <meta content="width=device-width, initial-scale=1.0, maximum-scale=1.0" name="viewport"/>
#   <meta content="exploring the world with 1s and 0s" name="description"/>
#   <meta content="exploring the world with 1s and 0s" property="og:description"/>
#   <meta content="aneesh durg" name="author"/>
#   <!--[if lt IE 9]>
#       <script src="http://html5shiv.googlecode.com/svn/trunk/html5.js"></script>
#     <![endif]-->
#   <link href="/style.css" rel="stylesheet" type="text/css"/>
#   <link href="/feed.xml" rel="alternate" title="aneesh durg - exploring the world with 1s and 0s" type="application/rss+xml"/>
#   <!-- Created with Jekyll Now - http://github.com/barryclark/jekyll-now -->
#  </head>
#  <script>
#   // Always use https when not served locally
#     if (window.location.host.includes("aneeshdurg.me") &&
#         window.location.protocol != "https:")
#       window.location.protocol = "https:";
#  </script>
#  <body>
#   <div class="wrapper-masthead">
#    <div class="container">
#     <header class="masthead clearfix">
#      <a class="site-avatar" href="/">
#       <img src="/static/images/me.jpg"/>
#      </a>
#      <div class="site-info">
#       <h1 class="site-name">
#        <a href="/">
#         aneesh durg
#        </a>
#       </h1>
#       <p class="site-description" id="site-description">
#        exploring the world with 1s and 0s
#       </p>
#      </div>
#      <nav>
#       <a href="/resume/resume.pdf">
#        resume
#       </a>
#       <a href="/blog/">
#        blog
#       </a>
#      </nav>
#     </header>
#    </div>
#   </div>
#   <div class="container" id="main" role="main">
#    <div class="posts">
#     <a name="2022">
#     </a>
#     <a href="#2022">
#      <p>
#       2022
#      </p>
#     </a>
#     <hr/>
#     <div style="margin-left: 0em">
#      <a name="2022-June">
#      </a>
#      <a href="#2022-June">
#       <p>
#        June
#       </p>
#      </a>
#      <hr style="border: 1px dashed"/>
#     </div>
#     <article class="post" style="margin-left: 2em">
#      <h1>
#       <a href="/posts/2022-06-29-circle-packing/">
#        interactive real time circle packing
#       </a>
#      </h1>
#      <div class="entry">
#       <p>
#        Try out my circle packing project with your webcam!
#       </p>
#      </div>
#      <a class="read-more" href="/posts/2022-06-29-circle-packing/">
#       Read More
#      </a>
#     </article>
#     <article class="post" style="margin-left: 2em">
#      <h1>
#       <a href="/posts/2022-06-23-circle-packing/">
#        real time circle packing - animated edition!
#       </a>
#      </h1>
#      <div class="entry">
#       <p>
#        In which the author finally “finishes” a project. We finally have real time
# circle packing!
#       </p>
#      </div>
#      <a class="read-more" href="/posts/2022-06-23-circle-packing/">
#       Read More
#      </a>
#     </article>
#     <article class="post" style="margin-left: 2em">
#      <h1>
#       <a href="/posts/2022-06-17-circle-packing/">
#        real time circle packing - now in real time!
#       </a>
#      </h1>
#      <div class="entry">
#       <p>
#        Breathing life into what I thought was an abandonded project.
#       </p>
#      </div>
#      <a class="read-more" href="/posts/2022-06-17-circle-packing/">
#       Read More
#      </a>
#     </article>
#     <br/>
#     <div style="margin-left: 0em">
#      <a name="2022-March">
#      </a>
#      <a href="#2022-March">
#       <p>
#        March
#       </p>
#      </a>
#      <hr style="border: 1px dashed"/>
#     </div>
#     <article class="post" style="margin-left: 2em">
#      <h1>
#       <a href="/posts/2022-03-24-pysh/">
#        pysh - a script that's valid python AND valid bash?!
#       </a>
#      </h1>
#      <div class="entry">
#       <p>
#        “God is dead. God remains dead. And we have killed him. How shall we comfort
# ourselves, the murderers of all murderers?”
#       </p>
#      </div>
#      <a class="read-more" href="/posts/2022-03-24-pysh/">
#       Read More
#      </a>
#     </article>
#     <br/>
#     <a name="2021">
#     </a>
#     <a href="#2021">
#      <p>
#       2021
#      </p>
#     </a>
#     <hr/>
#     <div style="margin-left: 0em">
#      <a name="2021-December">
#      </a>
#      <a href="#2021-December">
#       <p>
#        December
#       </p>
#      </a>
#      <hr style="border: 1px dashed"/>
#     </div>
#     <article class="post" style="margin-left: 2em">
#      <h1>
#       <a href="/posts/2021-12-29-building-a-fractal/">
#        building a fractal - episode 1
#       </a>
#      </h1>
#      <div class="entry">
#       <p>
#        Let’s try to construct some fractals!
#       </p>
#      </div>
#      <a class="read-more" href="/posts/2021-12-29-building-a-fractal/">
#       Read More
#      </a>
#     </article>
#     <br/>
#     <div style="margin-left: 0em">
#      <a name="2021-July">
#      </a>
#      <a href="#2021-July">
#       <p>
#        July
#       </p>
#      </a>
#      <hr style="border: 1px dashed"/>
#     </div>
#     <article class="post" style="margin-left: 2em">
#      <h1>
#       <a href="/posts/2021-07-16-circle-packing/">
#        real time circle packing - now with WebGL!
#       </a>
#      </h1>
#      <div class="entry">
#       <p>
#        I totally ignored my plan from the previous post, and tried to parallelize
# things with WebGL. Read more to find out what happened!
#       </p>
#      </div>
#      <a class="read-more" href="/posts/2021-07-16-circle-packing/">
#       Read More
#      </a>
#     </article>
#     <article class="post" style="margin-left: 2em">
#      <h1>
#       <a href="/posts/2021-07-15-circle-packing/">
#        the journey towards real time circle packing
#       </a>
#      </h1>
#      <div class="entry">
#       <p>
#        a journey for aesthetics and speed
#       </p>
#      </div>
#      <a class="read-more" href="/posts/2021-07-15-circle-packing/">
#       Read More
#      </a>
#     </article>
#     <br/>
#     <div style="margin-left: 0em">
#      <a name="2021-May">
#      </a>
#      <a href="#2021-May">
#       <p>
#        May
#       </p>
#      </a>
#      <hr style="border: 1px dashed"/>
#     </div>
#     <article class="post" style="margin-left: 2em">
#      <h1>
#       <a href="/posts/2021-05-1-rpgn/">
#        the tale of rpg-n
#       </a>
#      </h1>
#      <div class="entry">
#       <p>
#        Two years ago I started writing an engine for a visual novel/rpg system. I
# totally forgot about it, and I’ve decided to start over. This post will dive
# into an analysis of what I got right and wrong the first time around and what
# learnings I have from an unfinished project.
#       </p>
#      </div>
#      <a class="read-more" href="/posts/2021-05-1-rpgn/">
#       Read More
#      </a>
#     </article>
#     <br/>
#     <div style="margin-left: 0em">
#      <a name="2021-March">
#      </a>
#      <a href="#2021-March">
#       <p>
#        March
#       </p>
#      </a>
#      <hr style="border: 1px dashed"/>
#     </div>
#     <article class="post" style="margin-left: 2em">
#      <h1>
#       <a href="/posts/2021-03-20-whats-in-my-bookmarks/">
#        What's in my bookmarks?
#       </a>
#      </h1>
#      <div class="entry">
#       <p>
#        I decided to sort my bookmarks and thought it might be fun to write about it.
#       </p>
#      </div>
#      <a class="read-more" href="/posts/2021-03-20-whats-in-my-bookmarks/">
#       Read More
#      </a>
#     </article>
#     <br/>
#     <div style="margin-left: 0em">
#      <a name="2021-February">
#      </a>
#      <a href="#2021-February">
#       <p>
#        February
#       </p>
#      </a>
#      <hr style="border: 1px dashed"/>
#     </div>
#     <article class="post" style="margin-left: 2em">
#      <h1>
#       <a href="/posts/2021-02-15-woes-with-windows/">
#        my woes with windows
#       </a>
#      </h1>
#      <div class="entry">
#       <p>
#        I tried switching back to windows, it was an adventure.
#       </p>
#      </div>
#      <a class="read-more" href="/posts/2021-02-15-woes-with-windows/">
#       Read More
#      </a>
#     </article>
#     <article class="post" style="margin-left: 2em">
#      <h1>
#       <a href="/posts/2021-01-18-video-synth-experiments/">
#        Video Synth Experiments
#       </a>
#      </h1>
#      <div class="entry">
#       <p>
#        Some patches from my
#        <a href="/video-synth">
#         video synthesizer
#        </a>
#       </p>
#      </div>
#      <a class="read-more" href="/posts/2021-01-18-video-synth-experiments/">
#       Read More
#      </a>
#     </article>
#     <br/>
#     <div style="margin-left: 0em">
#      <a name="2021-January">
#      </a>
#      <a href="#2021-January">
#       <p>
#        January
#       </p>
#      </a>
#      <hr style="border: 1px dashed"/>
#     </div>
#     <article class="post" style="margin-left: 2em">
#      <h1>
#       <a href="/posts/Genuary 2021-day30/">
#        Genuary 2021 - day 30
#       </a>
#      </h1>
#      <div class="entry">
#       <p>
#        Flocks using
#        <a href="/posts/Genuary%202021">
#         day4’s butterflies
#        </a>
#        for
#        <a href="https://genuary2021.github.io/">
#         #genuary2021
#        </a>
#       </p>
#      </div>
#      <a class="read-more" href="/posts/Genuary 2021-day30/">
#       Read More
#      </a>
#     </article>
#     <article class="post" style="margin-left: 2em">
#      <h1>
#       <a href="/posts/Genuary 2021-day29/">
#        Genuary 2021 - day 29
#       </a>
#      </h1>
#      <div class="entry">
#       <p>
#        It’s a dance party, but with polygons! (for
#        <a href="https://genuary2021.github.io/">
#         #genuary2021
#        </a>
#        )
#       </p>
#      </div>
#      <a class="read-more" href="/posts/Genuary 2021-day29/">
#       Read More
#      </a>
#     </article>
#     <article class="post" style="margin-left: 2em">
#      <h1>
#       <a href="/posts/Genuary 2021-day20/">
#        Genuary 2021 - day 20
#       </a>
#      </h1>
#      <div class="entry">
#       <p>
#        Computing MSTs of planar graphs for
#        <a href="https://genuary2021.github.io/">
#         #genuary2021
#        </a>
#       </p>
#      </div>
#      <a class="read-more" href="/posts/Genuary 2021-day20/">
#       Read More
#      </a>
#     </article>
#     <article class="post" style="margin-left: 2em">
#      <h1>
#       <a href="/posts/Genuary 2021-day19/">
#        Genuary 2021 - day 19
#       </a>
#      </h1>
#      <div class="entry">
#       <p>
#        Exploring randomness for
#        <a href="https://genuary2021.github.io/">
#         #genuary2021
#        </a>
#       </p>
#      </div>
#      <a class="read-more" href="/posts/Genuary 2021-day19/">
#       Read More
#      </a>
#     </article>
#     <article class="post" style="margin-left: 2em">
#      <h1>
#       <a href="/posts/2021-01-18-variations/">
#        Variations on a theme
#       </a>
#      </h1>
#      <div class="entry">
#       <p>
#        Some looping animations made with my
#        <a href="/video-synth">
#         video synthesizer
#        </a>
#        that have common properties.
#       </p>
#      </div>
#      <a class="read-more" href="/posts/2021-01-18-variations/">
#       Read More
#      </a>
#     </article>
#     <article class="post" style="margin-left: 2em">
#      <h1>
#       <a href="/posts/Genuary 2021-day17/">
#        Genuary 2021 - day 17
#       </a>
#      </h1>
#      <div class="entry">
#       <p>
#        Drawing some art with lines for
#        <a href="https://genuary2021.github.io/">
#         #genuary2021
#        </a>
#       </p>
#      </div>
#      <a class="read-more" href="/posts/Genuary 2021-day17/">
#       Read More
#      </a>
#     </article>
#     <article class="post" style="margin-left: 2em">
#      <h1>
#       <a href="/posts/2021-01-16-color-reactor/">
#        Color Reactor
#       </a>
#      </h1>
#      <div class="entry">
#       <p>
#        A looping animation made with my
#        <a href="/video-synth">
#         video synthesizer
#        </a>
#       </p>
#      </div>
#      <a class="read-more" href="/posts/2021-01-16-color-reactor/">
#       Read More
#      </a>
#     </article>
#     <article class="post" style="margin-left: 2em">
#      <h1>
#       <a href="/posts/2021-01-15-real-time-pixelator/">
#        Real time pixelator
#       </a>
#      </h1>
#      <div class="entry">
#       <p>
#        A faster version of my
#        <a href="/posts/2021-01-14-pixelator/">
#         pixelator
#        </a>
#       </p>
#      </div>
#      <a class="read-more" href="/posts/2021-01-15-real-time-pixelator/">
#       Read More
#      </a>
#     </article>
#     <article class="post" style="margin-left: 2em">
#      <h1>
#       <a href="/posts/2021-01-14-pixelator/">
#        Pixelator
#       </a>
#      </h1>
#      <div class="entry">
#       <p>
#        A quick tool to pixelate images with a limited color palette
#       </p>
#      </div>
#      <a class="read-more" href="/posts/2021-01-14-pixelator/">
#       Read More
#      </a>
#     </article>
#     <article class="post" style="margin-left: 2em">
#      <h1>
#       <a href="/posts/Genuary 2021-day14/">
#        Genuary 2021 - day 14
#       </a>
#      </h1>
#      <div class="entry">
#       <p>
#        Revisiting
#        <a href="/posts/Genuary%202021">
#         day4’s butterflies
#        </a>
#        for
#        <a href="https://genuary2021.github.io/">
#         #genuary2021
#        </a>
#       </p>
#      </div>
#      <a class="read-more" href="/posts/Genuary 2021-day14/">
#       Read More
#      </a>
#     </article>
#     <article class="post" style="margin-left: 2em">
#      <h1>
#       <a href="/posts/Genuary 2021-day10-12/">
#        Genuary 2021 - day 12
#       </a>
#      </h1>
#      <div class="entry">
#       <p>
#        Making a collage using picsum for
#        <a href="https://genuary2021.github.io/">
#         #genuary2021
#        </a>
#       </p>
#      </div>
#      <a class="read-more" href="/posts/Genuary 2021-day10-12/">
#       Read More
#      </a>
#     </article>
#     <article class="post" style="margin-left: 2em">
#      <h1>
#       <a href="/posts/Genuary 2021-day10-11/">
#        Genuary 2021 - days 10+11
#       </a>
#      </h1>
#      <div class="entry">
#       <p>
#        Combining two prompts of
#        <a href="https://genuary2021.github.io/">
#         #genuary2021
#        </a>
#        into a
# audio based tree generator!
#       </p>
#      </div>
#      <a class="read-more" href="/posts/Genuary 2021-day10-11/">
#       Read More
#      </a>
#     </article>
#     <article class="post" style="margin-left: 2em">
#      <h1>
#       <a href="/posts/bash-raytracer/">
#        Making a raytracer - but in bash
#       </a>
#      </h1>
#      <div class="entry">
#       <p>
#        Inspired by the
#        <a href="https://github.com/64/cmake-raytracer">
#         CMake raytracer
#        </a>
#        , I ported it to
#        <a href="https://github.com/aneeshdurg/bash-raytracer">
#         bash
#        </a>
#        .
#       </p>
#      </div>
#      <a class="read-more" href="/posts/bash-raytracer/">
#       Read More
#      </a>
#     </article>
#     <article class="post" style="margin-left: 2em">
#      <h1>
#       <a href="/posts/Genuary 2021-day8/">
#        Genuary 2021 - day 8
#       </a>
#      </h1>
#      <div class="entry">
#       <p>
#        Playing around with L-Systems for
#        <a href="https://genuary2021.github.io/">
#         #genuary2021
#        </a>
#       </p>
#      </div>
#      <a class="read-more" href="/posts/Genuary 2021-day8/">
#       Read More
#      </a>
#     </article>
#     <article class="post" style="margin-left: 2em">
#      <h1>
#       <a href="/posts/Genuary 2021-day6/">
#        Genuary 2021 - day 6
#       </a>
#      </h1>
#      <div class="entry">
#       <p>
#        Drawing triangles for
#        <a href="https://genuary2021.github.io/">
#         #genuary2021
#        </a>
#       </p>
#      </div>
#      <a class="read-more" href="/posts/Genuary 2021-day6/">
#       Read More
#      </a>
#     </article>
#     <article class="post" style="margin-left: 2em">
#      <h1>
#       <a href="/posts/Genuary 2021-day5/">
#        Genuary 2021 - day 5
#       </a>
#      </h1>
#      <div class="entry">
#       <p>
#        Another day of
#        <a href="https://genuary2021.github.io">
#         #genuary
#        </a>
#        - this time with vaporwave
#       </p>
#      </div>
#      <a class="read-more" href="/posts/Genuary 2021-day5/">
#       Read More
#      </a>
#     </article>
#     <article class="post" style="margin-left: 2em">
#      <h1>
#       <a href="/posts/Genuary 2021/">
#        Genuary 2021 - day 4
#       </a>
#      </h1>
#      <div class="entry">
#       <p>
#        I saw
#        <a href="https://genuary2021.github.io/">
#         #genuary2021
#        </a>
#        on twitter and wanted in on the fun.
#       </p>
#      </div>
#      <a class="read-more" href="/posts/Genuary 2021/">
#       Read More
#      </a>
#     </article>
#     <br/>
#     <a name="2020">
#     </a>
#     <a href="#2020">
#      <p>
#       2020
#      </p>
#     </a>
#     <hr/>
#     <div style="margin-left: 0em">
#      <a name="2020-December">
#      </a>
#      <a href="#2020-December">
#       <p>
#        December
#       </p>
#      </a>
#      <hr style="border: 1px dashed"/>
#     </div>
#     <article class="post" style="margin-left: 2em">
#      <h1>
#       <a href="/posts/things-i-wish-id-learned-in-school/">
#        Things I wish I'd learned in school
#       </a>
#      </h1>
#      <div class="entry">
#       <p>
#        It’s been about 1.5 years since I graduated! Here are some things that I wish
# I’d learned, or that I wish were taught in school.
#       </p>
#      </div>
#      <a class="read-more" href="/posts/things-i-wish-id-learned-in-school/">
#       Read More
#      </a>
#     </article>
#     <br/>
#     <div style="margin-left: 0em">
#      <a name="2020-September">
#      </a>
#      <a href="#2020-September">
#       <p>
#        September
#       </p>
#      </a>
#      <hr style="border: 1px dashed"/>
#     </div>
#     <article class="post" style="margin-left: 2em">
#      <h1>
#       <a href="/posts/dragon-fractal/">
#        Playing around with the dragon fractal
#       </a>
#      </h1>
#      <div class="entry">
#       <p>
#        Some experiments with my favorite fractal!
#       </p>
#      </div>
#      <a class="read-more" href="/posts/dragon-fractal/">
#       Read More
#      </a>
#     </article>
#     <article class="post" style="margin-left: 2em">
#      <h1>
#       <a href="/posts/six-months-of-isolation/">
#        Six Months of Isolation
#       </a>
#      </h1>
#      <div class="entry">
#       <p>
#        It’s been 6 months since I entered the “new normal”, what have I been up to?
#       </p>
#      </div>
#      <a class="read-more" href="/posts/six-months-of-isolation/">
#       Read More
#      </a>
#     </article>
#     <br/>
#     <div style="margin-left: 0em">
#      <a name="2020-August">
#      </a>
#      <a href="#2020-August">
#       <p>
#        August
#       </p>
#      </a>
#      <hr style="border: 1px dashed"/>
#     </div>
#     <article class="post" style="margin-left: 2em">
#      <h1>
#       <a href="/posts/pretty-colors/">
#        Pretty Colors
#       </a>
#      </h1>
#      <div class="entry">
#       <p>
#        Playing around with the illusion of color
#       </p>
#      </div>
#      <a class="read-more" href="/posts/pretty-colors/">
#       Read More
#      </a>
#     </article>
#     <article class="post" style="margin-left: 2em">
#      <h1>
#       <a href="/posts/visualizing-mandelbrot/">
#        Visualizing the Mandelbrot Set using WebGL
#       </a>
#      </h1>
#      <div class="entry">
#       <p>
#        Can’t call myself a math nerd without doing this right?
#       </p>
#      </div>
#      <a class="read-more" href="/posts/visualizing-mandelbrot/">
#       Read More
#      </a>
#     </article>
#     <article class="post" style="margin-left: 2em">
#      <h1>
#       <a href="/posts/building-a-keyboard/">
#        Building a keyboard (part 1)
#       </a>
#      </h1>
#      <div class="entry">
#       <p>
#        I’ve built some mechanical keyboards before, but maybe it’s time I built one
# from scratch.
#       </p>
#      </div>
#      <a class="read-more" href="/posts/building-a-keyboard/">
#       Read More
#      </a>
#     </article>
#     <br/>
#     <div style="margin-left: 0em">
#      <a name="2020-July">
#      </a>
#      <a href="#2020-July">
#       <p>
#        July
#       </p>
#      </a>
#      <hr style="border: 1px dashed"/>
#     </div>
#     <article class="post" style="margin-left: 2em">
#      <h1>
#       <a href="/posts/finding-the-area-of-some-semicircles/">
#        Finding the area of some semicircles
#       </a>
#      </h1>
#      <div class="entry">
#       <p>
#        I was recently shown the following statement and wanted to prove it. Given a
# circle of radius \(r\) centered at the origin, for \( \forall p \in (-r,
# r)\) , construct two semi circles that intersect uniquely at \((p, 0)\), such
# that each semi circle only intersects with the circle of radius \(r\) exactly
# twice, and each semicircle’s centers are on the x-axis.
# The sum of the areas of the two semicircles is half the area of the
# enclosing circle (\(\frac{\pi r^2}{2}\)). This post is a proof with
# visualizations!
#       </p>
#      </div>
#      <a class="read-more" href="/posts/finding-the-area-of-some-semicircles/">
#       Read More
#      </a>
#     </article>
#     <br/>
#     <div style="margin-left: 0em">
#      <a name="2020-March">
#      </a>
#      <a href="#2020-March">
#       <p>
#        March
#       </p>
#      </a>
#      <hr style="border: 1px dashed"/>
#     </div>
#     <article class="post" style="margin-left: 2em">
#      <h1>
#       <a href="/posts/computing-digits-of-pi/">
#        Computing digits of Pi
#       </a>
#      </h1>
#      <div class="entry">
#       <p>
#        Happy \( \pi \) day! In the spirit of \( \pi \) day, I wanted to compute the
# millionth digit of \( \pi \) using my GPU!
#       </p>
#      </div>
#      <a class="read-more" href="/posts/computing-digits-of-pi/">
#       Read More
#      </a>
#     </article>
#     <article class="post" style="margin-left: 2em">
#      <h1>
#       <a href="/posts/webgl-game-of-life/">
#        WebGL game of life
#       </a>
#      </h1>
#      <div class="entry">
#       <p>
#        In my continued efforts to learn webGL, I wanted to make an engine for conway’s
# game of life. Click on this post for final result!
#       </p>
#      </div>
#      <a class="read-more" href="/posts/webgl-game-of-life/">
#       Read More
#      </a>
#     </article>
#     <br/>
#     <div style="margin-left: 0em">
#      <a name="2020-February">
#      </a>
#      <a href="#2020-February">
#       <p>
#        February
#       </p>
#      </a>
#      <hr style="border: 1px dashed"/>
#     </div>
#     <article class="post" style="margin-left: 2em">
#      <h1>
#       <a href="/posts/making-a-hexel-effect/">
#        Making a hexel effect
#       </a>
#      </h1>
#      <div class="entry">
#       <p>
#        I’ve been trying to re-learn webGL lately. To get myself started, I’ve been
# trying to implement some simple visual effects as fragment shaders. In this post
# I’m going to be detailing how I made a hexel effect.
#       </p>
#      </div>
#      <a class="read-more" href="/posts/making-a-hexel-effect/">
#       Read More
#      </a>
#     </article>
#     <br/>
#     <a name="2018">
#     </a>
#     <a href="#2018">
#      <p>
#       2018
#      </p>
#     </a>
#     <hr/>
#     <div style="margin-left: 0em">
#      <a name="2018-December">
#      </a>
#      <a href="#2018-December">
#       <p>
#        December
#       </p>
#      </a>
#      <hr style="border: 1px dashed"/>
#     </div>
#     <article class="post" style="margin-left: 2em">
#      <h1>
#       <a href="/posts/arduino-keyboard-mouse">
#        Arduino Keyboard Mouse
#       </a>
#      </h1>
#      <div class="entry">
#       <p>
#        Recently, I came across
#        <a href="http://mitchtech.net/arduino-usb-hid-keyboard/">
#         this post
#        </a>
#        which I found pretty interesting as
# a fellow owner of a arduino UNO. I also had a few cherry switches left over from a recent mechanical keyboard build, so
# I wanted to try my hand at building a keyboard/mouse from scratch as a learning exercise. You can find my current
# progress on this project over at
#        <a href="https://github.com/aneeshdurg/arduino-keyboard/">
#         https://github.com/aneeshdurg/arduino-keyboard/
#        </a>
#        .
#       </p>
#      </div>
#      <a class="read-more" href="/posts/arduino-keyboard-mouse">
#       Read More
#      </a>
#     </article>
#     <br/>
#     <div style="margin-left: 0em">
#      <a name="2018-March">
#      </a>
#      <a href="#2018-March">
#       <p>
#        March
#       </p>
#      </a>
#      <hr style="border: 1px dashed"/>
#     </div>
#     <article class="post" style="margin-left: 2em">
#      <h1>
#       <a href="/posts/wu-tang-clan">
#        Wu-Tang Clan in the Terminal
#       </a>
#      </h1>
#      <div class="entry">
#       <p>
#        Hi everyone! It’s been a long time since I’ve updated my website (probably should more often…I’m paying for the hosting anyway…). Today I’d like to share with y’all something short and silly I made while trying to not think about my midterms. I’ve decided to try writing this in a tutorial format, with the intended readers being people who’re new to bash scripting.
#       </p>
#      </div>
#      <a class="read-more" href="/posts/wu-tang-clan">
#       Read More
#      </a>
#     </article>
#     <br/>
#     <a name="2017">
#     </a>
#     <a href="#2017">
#      <p>
#       2017
#      </p>
#     </a>
#     <hr/>
#     <div style="margin-left: 0em">
#      <a name="2017-May">
#      </a>
#      <a href="#2017-May">
#       <p>
#        May
#       </p>
#      </a>
#      <hr style="border: 1px dashed"/>
#     </div>
#     <article class="post" style="margin-left: 2em">
#      <h1>
#       <a href="/posts/mangareaderfs">
#        MangareaderFS
#       </a>
#      </h1>
#      <div class="entry">
#       <p>
#        Building a FUSE filesystem interface to mangareader
#       </p>
#      </div>
#      <a class="read-more" href="/posts/mangareaderfs">
#       Read More
#      </a>
#     </article>
#     <br/>
#     <div style="margin-left: 0em">
#      <a name="2017-April">
#      </a>
#      <a href="#2017-April">
#       <p>
#        April
#       </p>
#      </a>
#      <hr style="border: 1px dashed"/>
#     </div>
#     <article class="post" style="margin-left: 2em">
#      <h1>
#       <a href="/posts/BashClock/">
#        Bash Clock
#       </a>
#      </h1>
#      <div class="entry">
#       <p>
#        Hi all, it’s been a while since my last post. (Un)fortunately this isn’t a post about my
#        <a href="http://www.browserhaskell.tk/editor">
#         more exciting Haskell project
#        </a>
#        , but about a quick terminal enhancement I cooked up today!
#       </p>
#      </div>
#      <a class="read-more" href="/posts/BashClock/">
#       Read More
#      </a>
#     </article>
#     <br/>
#     <div style="margin-left: 0em">
#      <a name="2017-January">
#      </a>
#      <a href="#2017-January">
#       <p>
#        January
#       </p>
#      </a>
#      <hr style="border: 1px dashed"/>
#     </div>
#     <article class="post" style="margin-left: 2em">
#      <h1>
#       <a href="/posts/haskell-game-of-life/">
#        Haskell Game of Life
#       </a>
#      </h1>
#      <div class="entry">
#       <p>
#        Hello, my possibly (probably) nonexistant readers! It’s been a while since I’ve written anything. For starters, happy new year!
#       </p>
#      </div>
#      <a class="read-more" href="/posts/haskell-game-of-life/">
#       Read More
#      </a>
#     </article>
#     <br/>
#     <a name="2016">
#     </a>
#     <a href="#2016">
#      <p>
#       2016
#      </p>
#     </a>
#     <hr/>
#     <div style="margin-left: 0em">
#      <a name="2016-August">
#      </a>
#      <a href="#2016-August">
#       <p>
#        August
#       </p>
#      </a>
#      <hr style="border: 1px dashed"/>
#     </div>
#     <article class="post" style="margin-left: 2em">
#      <h1>
#       <a href="/d3Fireworks/">
#        d3.js Fireworks
#       </a>
#      </h1>
#      <div class="entry">
#       <p>
#        I was playing around with d3.js and made this animation thing. Move the cursor to experience it and click to see the code!
#       </p>
#      </div>
#      <a class="read-more" href="/d3Fireworks/">
#       Read More
#      </a>
#     </article>
#     <br/>
#     <div style="margin-left: 0em">
#      <a name="2016-June">
#      </a>
#      <a href="#2016-June">
#       <p>
#        June
#       </p>
#      </a>
#      <hr style="border: 1px dashed"/>
#     </div>
#     <article class="post" style="margin-left: 2em">
#      <h1>
#       <a href="/posts/pokemon-bashrc/">
#        Pokemon .bashrc
#       </a>
#      </h1>
#      <div class="entry">
#       <p>
#        Recently, I’ve been playing around with my .bashrc file on my laptop and trying to make the time I spend at my laptop a little more exciting. Additionaly, I’ve been a huge fan of the pokemon franchise since I was young enough to frolick through meadows without incurring strange looks from others. I decided to bring the world of pokemon into my terminal.
#       </p>
#      </div>
#      <a class="read-more" href="/posts/pokemon-bashrc/">
#       Read More
#      </a>
#     </article>
#     <article class="post" style="margin-left: 2em">
#      <h1>
#       <a href="/posts/Smart-Zoom/">
#        Smart Zoom - a chrome extension using getUserMedia
#       </a>
#      </h1>
#      <div class="entry">
#       <p>
#        I recently made a chrome extension called
#        <a href="https://chrome.google.com/webstore/detail/smartzoom/edhnoodpplcedbalpigcmgojicolfdbg">
#         smartZoom
#        </a>
#        which makes chrome set the browser’s zoom level based off of the user’s proximity to their laptop using getUserMedia.
# While I wouldn’t say it’s entirely complete and working they way I want it to, it can definately be considered a proof of concept.
#       </p>
#      </div>
#      <a class="read-more" href="/posts/Smart-Zoom/">
#       Read More
#      </a>
#     </article>
#     <br/>
#     <div style="margin-left: 0em">
#      <a name="2016-May">
#      </a>
#      <a href="#2016-May">
#       <p>
#        May
#       </p>
#      </a>
#      <hr style="border: 1px dashed"/>
#     </div>
#     <article class="post" style="margin-left: 2em">
#      <h1>
#       <a href="/posts/CameraTheremin">
#        Camera Theremin
#       </a>
#      </h1>
#      <div class="entry">
#       <p>
#        This post details how I made the
#        <a href="https://aneeshdurg.github.io/CameraTheremin/">
#         CameraTheremin
#        </a>
#        . I hope you find it useful.
#       </p>
#      </div>
#      <a class="read-more" href="/posts/CameraTheremin">
#       Read More
#      </a>
#     </article>
#     <article class="post" style="margin-left: 2em">
#      <h1>
#       <a href="/posts/Hello-World/">
#        Hello World!
#       </a>
#      </h1>
#      <div class="entry">
#       <h2 id="its-my-first-post">
#        It’s my first post!
#       </h2>
#      </div>
#      <a class="read-more" href="/posts/Hello-World/">
#       Read More
#      </a>
#     </article>
#    </div>
#   </div>
#   <div class="wrapper-footer">
#    <div class="container">
#     <footer class="footer">
#      <a href="mailto:aneeshdurg17@gmail.com">
#       <i class="svg-icon email">
#       </i>
#      </a>
#      <a href="https://github.com/aneeshdurg">
#       <i class="svg-icon github">
#       </i>
#      </a>
#      <a href="https://www.twitter.com/ad29111">
#       <i class="svg-icon twitter">
#       </i>
#      </a>
#     </footer>
#    </div>
#   </div>
#  </body>
# </html>

# %%
# Get the title of Guido's webpage: guido_title
aneesh_title = soup.title

print(aneesh_title)
# Out:
# <title>aneesh durg – exploring the world with 1s and 0s</title>

# %%
# Get Guido's text: guido_text
aneesh_text = soup.get_text()

# Print Guido's text to the shell
print(aneesh_text)
# Out:
# aneesh durg – exploring the world with 1s and 0s
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# aneesh durg
# exploring the world with 1s and 0s
#
#
# resume
# blog
#
#
#
#
#
#
#
# 2022
#
#
#
# June
#
#
#
# interactive real time circle packing
#
# Try out my circle packing project with your webcam!
#
# Read More
#
#
# real time circle packing - animated edition!
#
# In which the author finally “finishes” a project. We finally have real time
# circle packing!
#
# Read More
#
#
# real time circle packing - now in real time!
#
# Breathing life into what I thought was an abandonded project.
#
# Read More
#
#
#
#
# March
#
#
#
# pysh - a script that's valid python AND valid bash?!
#
# “God is dead. God remains dead. And we have killed him. How shall we comfort
# ourselves, the murderers of all murderers?”
#
# Read More
#
#
#
# 2021
#
#
#
# December
#
#
#
# building a fractal - episode 1
#
# Let’s try to construct some fractals!
#
# Read More
#
#
#
#
# July
#
#
#
# real time circle packing - now with WebGL!
#
# I totally ignored my plan from the previous post, and tried to parallelize
# things with WebGL. Read more to find out what happened!
#
# Read More
#
#
# the journey towards real time circle packing
#
# a journey for aesthetics and speed
#
# Read More
#
#
#
#
# May
#
#
#
# the tale of rpg-n
#
# Two years ago I started writing an engine for a visual novel/rpg system. I
# totally forgot about it, and I’ve decided to start over. This post will dive
# into an analysis of what I got right and wrong the first time around and what
# learnings I have from an unfinished project.
#
# Read More
#
#
#
#
# March
#
#
#
# What's in my bookmarks?
#
# I decided to sort my bookmarks and thought it might be fun to write about it.
#
# Read More
#
#
#
#
# February
#
#
#
# my woes with windows
#
# I tried switching back to windows, it was an adventure.
#
# Read More
#
#
# Video Synth Experiments
#
# Some patches from my video synthesizer
#
# Read More
#
#
#
#
# January
#
#
#
# Genuary 2021 - day 30
#
# Flocks using day4’s butterflies for #genuary2021
#
# Read More
#
#
# Genuary 2021 - day 29
#
# It’s a dance party, but with polygons! (for #genuary2021)
#
# Read More
#
#
# Genuary 2021 - day 20
#
# Computing MSTs of planar graphs for #genuary2021
#
# Read More
#
#
# Genuary 2021 - day 19
#
# Exploring randomness for #genuary2021
#
# Read More
#
#
# Variations on a theme
#
# Some looping animations made with my video synthesizer
# that have common properties.
#
# Read More
#
#
# Genuary 2021 - day 17
#
# Drawing some art with lines for #genuary2021
#
# Read More
#
#
# Color Reactor
#
# A looping animation made with my video synthesizer
#
# Read More
#
#
# Real time pixelator
#
# A faster version of my pixelator
#
# Read More
#
#
# Pixelator
#
# A quick tool to pixelate images with a limited color palette
#
# Read More
#
#
# Genuary 2021 - day 14
#
# Revisiting day4’s butterflies for #genuary2021
#
# Read More
#
#
# Genuary 2021 - day 12
#
# Making a collage using picsum for #genuary2021
#
# Read More
#
#
# Genuary 2021 - days 10+11
#
# Combining two prompts of #genuary2021 into a
# audio based tree generator!
#
# Read More
#
#
# Making a raytracer - but in bash
#
# Inspired by the CMake raytracer, I ported it to bash.
#
# Read More
#
#
# Genuary 2021 - day 8
#
# Playing around with L-Systems for #genuary2021
#
# Read More
#
#
# Genuary 2021 - day 6
#
# Drawing triangles for #genuary2021
#
# Read More
#
#
# Genuary 2021 - day 5
#
# Another day of #genuary - this time with vaporwave
#
# Read More
#
#
# Genuary 2021 - day 4
#
# I saw #genuary2021 on twitter and wanted in on the fun.
#
# Read More
#
#
#
# 2020
#
#
#
# December
#
#
#
# Things I wish I'd learned in school
#
# It’s been about 1.5 years since I graduated! Here are some things that I wish
# I’d learned, or that I wish were taught in school.
#
# Read More
#
#
#
#
# September
#
#
#
# Playing around with the dragon fractal
#
# Some experiments with my favorite fractal!
#
# Read More
#
#
# Six Months of Isolation
#
# It’s been 6 months since I entered the “new normal”, what have I been up to?
#
# Read More
#
#
#
#
# August
#
#
#
# Pretty Colors
#
# Playing around with the illusion of color
#
# Read More
#
#
# Visualizing the Mandelbrot Set using WebGL
#
# Can’t call myself a math nerd without doing this right?
#
# Read More
#
#
# Building a keyboard (part 1)
#
# I’ve built some mechanical keyboards before, but maybe it’s time I built one
# from scratch.
#
# Read More
#
#
#
#
# July
#
#
#
# Finding the area of some semicircles
#
# I was recently shown the following statement and wanted to prove it. Given a
# circle of radius \(r\) centered at the origin, for \( \forall p \in (-r,
# r)\) , construct two semi circles that intersect uniquely at \((p, 0)\), such
# that each semi circle only intersects with the circle of radius \(r\) exactly
# twice, and each semicircle’s centers are on the x-axis.
# The sum of the areas of the two semicircles is half the area of the
# enclosing circle (\(\frac{\pi r^2}{2}\)). This post is a proof with
# visualizations!
#
# Read More
#
#
#
#
# March
#
#
#
# Computing digits of Pi
#
# Happy \( \pi \) day! In the spirit of \( \pi \) day, I wanted to compute the
# millionth digit of \( \pi \) using my GPU!
#
# Read More
#
#
# WebGL game of life
#
# In my continued efforts to learn webGL, I wanted to make an engine for conway’s
# game of life. Click on this post for final result!
#
# Read More
#
#
#
#
# February
#
#
#
# Making a hexel effect
#
# I’ve been trying to re-learn webGL lately. To get myself started, I’ve been
# trying to implement some simple visual effects as fragment shaders. In this post
# I’m going to be detailing how I made a hexel effect.
#
# Read More
#
#
#
# 2018
#
#
#
# December
#
#
#
# Arduino Keyboard Mouse
#
# Recently, I came across this post which I found pretty interesting as
# a fellow owner of a arduino UNO. I also had a few cherry switches left over from a recent mechanical keyboard build, so
# I wanted to try my hand at building a keyboard/mouse from scratch as a learning exercise. You can find my current
# progress on this project over at https://github.com/aneeshdurg/arduino-keyboard/.
#
# Read More
#
#
#
#
# March
#
#
#
# Wu-Tang Clan in the Terminal
#
# Hi everyone! It’s been a long time since I’ve updated my website (probably should more often…I’m paying for the hosting anyway…). Today I’d like to share with y’all something short and silly I made while trying to not think about my midterms. I’ve decided to try writing this in a tutorial format, with the intended readers being people who’re new to bash scripting.
#
# Read More
#
#
#
# 2017
#
#
#
# May
#
#
#
# MangareaderFS
#
# Building a FUSE filesystem interface to mangareader
#
# Read More
#
#
#
#
# April
#
#
#
# Bash Clock
#
# Hi all, it’s been a while since my last post. (Un)fortunately this isn’t a post about my more exciting Haskell project, but about a quick terminal enhancement I cooked up today!
#
# Read More
#
#
#
#
# January
#
#
#
# Haskell Game of Life
#
# Hello, my possibly (probably) nonexistant readers! It’s been a while since I’ve written anything. For starters, happy new year!
#
# Read More
#
#
#
# 2016
#
#
#
# August
#
#
#
# d3.js Fireworks
#
# I was playing around with d3.js and made this animation thing. Move the cursor to experience it and click to see the code!
#
# Read More
#
#
#
#
# June
#
#
#
# Pokemon .bashrc
#
# Recently, I’ve been playing around with my .bashrc file on my laptop and trying to make the time I spend at my laptop a little more exciting. Additionaly, I’ve been a huge fan of the pokemon franchise since I was young enough to frolick through meadows without incurring strange looks from others. I decided to bring the world of pokemon into my terminal.
#
# Read More
#
#
# Smart Zoom - a chrome extension using getUserMedia
#
# I recently made a chrome extension called smartZoom which makes chrome set the browser’s zoom level based off of the user’s proximity to their laptop using getUserMedia.
# While I wouldn’t say it’s entirely complete and working they way I want it to, it can definately be considered a proof of concept.
#
# Read More
#
#
#
#
# May
#
#
#
# Camera Theremin
#
# This post details how I made the CameraTheremin. I hope you find it useful.
#
# Read More
#
#
# Hello World!
#
# It’s my first post!
#
# Read More

# %%
a_tags = soup.find_all('a')
for links in a_tags:
    print(links.get('href'))
# Out:
# /
# /
# /resume/resume.pdf
# /blog/
# None
# #2022
# None
# #2022-June
# /posts/2022-06-29-circle-packing/
# /posts/2022-06-29-circle-packing/
# /posts/2022-06-23-circle-packing/
# /posts/2022-06-23-circle-packing/
# /posts/2022-06-17-circle-packing/
# /posts/2022-06-17-circle-packing/
# None
# #2022-March
# /posts/2022-03-24-pysh/
# /posts/2022-03-24-pysh/
# None
# #2021
# None
# #2021-December
# /posts/2021-12-29-building-a-fractal/
# /posts/2021-12-29-building-a-fractal/
# None
# #2021-July
# /posts/2021-07-16-circle-packing/
# /posts/2021-07-16-circle-packing/
# /posts/2021-07-15-circle-packing/
# /posts/2021-07-15-circle-packing/
# None
# #2021-May
# /posts/2021-05-1-rpgn/
# /posts/2021-05-1-rpgn/
# None
# #2021-March
# /posts/2021-03-20-whats-in-my-bookmarks/
# /posts/2021-03-20-whats-in-my-bookmarks/
# None
# #2021-February
# /posts/2021-02-15-woes-with-windows/
# /posts/2021-02-15-woes-with-windows/
# /posts/2021-01-18-video-synth-experiments/
# /video-synth
# /posts/2021-01-18-video-synth-experiments/
# None
# #2021-January
# /posts/Genuary 2021-day30/
# /posts/Genuary%202021
# https://genuary2021.github.io/
# /posts/Genuary 2021-day30/
# /posts/Genuary 2021-day29/
# https://genuary2021.github.io/
# /posts/Genuary 2021-day29/
# /posts/Genuary 2021-day20/
# https://genuary2021.github.io/
# /posts/Genuary 2021-day20/
# /posts/Genuary 2021-day19/
# https://genuary2021.github.io/
# /posts/Genuary 2021-day19/
# /posts/2021-01-18-variations/
# /video-synth
# /posts/2021-01-18-variations/
# /posts/Genuary 2021-day17/
# https://genuary2021.github.io/
# /posts/Genuary 2021-day17/
# /posts/2021-01-16-color-reactor/
# /video-synth
# /posts/2021-01-16-color-reactor/
# /posts/2021-01-15-real-time-pixelator/
# /posts/2021-01-14-pixelator/
# /posts/2021-01-15-real-time-pixelator/
# /posts/2021-01-14-pixelator/
# /posts/2021-01-14-pixelator/
# /posts/Genuary 2021-day14/
# /posts/Genuary%202021
# https://genuary2021.github.io/
# /posts/Genuary 2021-day14/
# /posts/Genuary 2021-day10-12/
# https://genuary2021.github.io/
# /posts/Genuary 2021-day10-12/
# /posts/Genuary 2021-day10-11/
# https://genuary2021.github.io/
# /posts/Genuary 2021-day10-11/
# /posts/bash-raytracer/
# https://github.com/64/cmake-raytracer
# https://github.com/aneeshdurg/bash-raytracer
# /posts/bash-raytracer/
# /posts/Genuary 2021-day8/
# https://genuary2021.github.io/
# /posts/Genuary 2021-day8/
# /posts/Genuary 2021-day6/
# https://genuary2021.github.io/
# /posts/Genuary 2021-day6/
# /posts/Genuary 2021-day5/
# https://genuary2021.github.io
# /posts/Genuary 2021-day5/
# /posts/Genuary 2021/
# https://genuary2021.github.io/
# /posts/Genuary 2021/
# None
# #2020
# None
# #2020-December
# /posts/things-i-wish-id-learned-in-school/
# /posts/things-i-wish-id-learned-in-school/
# None
# #2020-September
# /posts/dragon-fractal/
# /posts/dragon-fractal/
# /posts/six-months-of-isolation/
# /posts/six-months-of-isolation/
# None
# #2020-August
# /posts/pretty-colors/
# /posts/pretty-colors/
# /posts/visualizing-mandelbrot/
# /posts/visualizing-mandelbrot/
# /posts/building-a-keyboard/
# /posts/building-a-keyboard/
# None
# #2020-July
# /posts/finding-the-area-of-some-semicircles/
# /posts/finding-the-area-of-some-semicircles/
# None
# #2020-March
# /posts/computing-digits-of-pi/
# /posts/computing-digits-of-pi/
# /posts/webgl-game-of-life/
# /posts/webgl-game-of-life/
# None
# #2020-February
# /posts/making-a-hexel-effect/
# /posts/making-a-hexel-effect/
# None
# #2018
# None
# #2018-December
# /posts/arduino-keyboard-mouse
# http://mitchtech.net/arduino-usb-hid-keyboard/
# https://github.com/aneeshdurg/arduino-keyboard/
# /posts/arduino-keyboard-mouse
# None
# #2018-March
# /posts/wu-tang-clan
# /posts/wu-tang-clan
# None
# #2017
# None
# #2017-May
# /posts/mangareaderfs
# /posts/mangareaderfs
# None
# #2017-April
# /posts/BashClock/
# http://www.browserhaskell.tk/editor
# /posts/BashClock/
# None
# #2017-January
# /posts/haskell-game-of-life/
# /posts/haskell-game-of-life/
# None
# #2016
# None
# #2016-August
# /d3Fireworks/
# /d3Fireworks/
# None
# #2016-June
# /posts/pokemon-bashrc/
# /posts/pokemon-bashrc/
# /posts/Smart-Zoom/
# https://chrome.google.com/webstore/detail/smartzoom/edhnoodpplcedbalpigcmgojicolfdbg
# /posts/Smart-Zoom/
# None
# #2016-May
# /posts/CameraTheremin
# https://aneeshdurg.github.io/CameraTheremin/
# /posts/CameraTheremin
# /posts/Hello-World/
# /posts/Hello-World/
# mailto:aneeshdurg17@gmail.com
# https://github.com/aneeshdurg
# https://www.twitter.com/ad29111
